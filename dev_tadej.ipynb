# %%
import numpy as np
import pandas as pd

from src.utils import train_val_test_split

# %%
! ls -lh train_data
# Out:
# total 567M
# -rw-rw-r-- 1 1000 1000 883K Apr 17 11:22 appl.csv
# -rw-rw-r-- 1 1000 1000 6.3M Apr 17 11:22 aum.csv
# -rw-rw-r-- 1 1000 1000  88M Apr 17 11:22 balance.csv
# -rw-rw-r-- 1 1000 1000 1.1M Apr 17 11:22 client.csv
# -rw-rw-r-- 1 1000 1000 6.4M Apr 17 11:22 com.csv
# -rw-rw-r-- 1 1000 1000 7.2M Apr 17 11:22 deals.csv
# -rw-rw-r-- 1 1000 1000  19K Apr 17 11:22 dict_mcc.csv
# -rw-rw-r-- 1 1000 1000 2.3M Apr 17 11:22 funnel.csv
# -rw-rw-r-- 1 1000 1000  11M Apr 17 11:22 payments.csv
# -rw-rw-r-- 1 1000 1000 446M Apr 17 11:22 trxn.csv

# %%
pd.read_csv('train_data/appl.csv').describe(include='all', percentiles=[])
# Out:
#            client_id month_end_dt appl_prod_group_name appl_prod_type_name  \
# count   1.203000e+04        12030                12030               12030
# unique           NaN           12                    3                   4
# top              NaN   2018-10-31                Cards         Debit cards
# freq             NaN         1520                 8307                4749
# mean    1.999111e+17          NaN                  NaN                 NaN
# std     5.350286e+18          NaN                  NaN                 NaN
# min    -9.220236e+18          NaN                  NaN                 NaN
# 50%     4.354937e+17          NaN                  NaN                 NaN
# max     9.223107e+18          NaN                  NaN                 NaN
#
#              appl_stts_name_dc appl_sale_channel_name
# count                     8567                  11966
# unique                      24                     10
# top     Issuance has been made                Network
# ...

# %%
pd.read_csv('train_data/aum.csv').describe(include='all', percentiles=[])
# Out:
#            client_id month_end_dt  balance_rur_amt      product_code
# count   1.173920e+05       117392     1.173920e+05            117392
# unique           NaN           10              NaN                 6
# top              NaN   2019-07-31              NaN  Current accounts
# freq             NaN        12467              NaN            107484
# mean    6.001097e+16          NaN     1.515352e+05               NaN
# std     5.316467e+18          NaN     7.092061e+05               NaN
# min    -9.220236e+18          NaN    -2.846000e+03               NaN
# 50%     1.037957e+17          NaN     1.330700e+04               NaN
# max     9.223107e+18          NaN     6.013248e+07               NaN

# %%
pd.read_csv('train_data/balance.csv').describe(include='all', percentiles=[])
# Out:
#            client_id      crncy_cd  eop_bal_sum_rur  min_bal_sum_rur  \
# count   1.194684e+06  1.193796e+06     1.194684e+06     1.194684e+06
# unique           NaN           NaN              NaN              NaN
# top              NaN           NaN              NaN              NaN
# freq             NaN           NaN              NaN              NaN
# mean    1.443874e+17  8.124211e+02    -1.181647e+01    -1.461774e+01
# std     5.300572e+18  2.510246e+01     3.934000e+02     4.255218e+02
# min    -9.221942e+18  3.300000e+01    -2.527200e+04    -2.527200e+04
# 50%     2.803692e+17  8.100000e+02     0.000000e+00     0.000000e+00
# max     9.223107e+18  9.780000e+02     7.827800e+04     8.002100e+04
#
#         max_bal_sum_rur  avg_bal_sum_rur month_end_dt prod_cat_name  \
# count      1.194684e+06     1.194684e+06      1194684       1192794
# unique              NaN              NaN           12            19
# top                 NaN              NaN   2019-08-31            KN
# ...

# %%
pd.read_csv('train_data/client.csv').describe(include='all', percentiles=[])
# Out:
#            client_id gender           age        region          city  \
# count   2.149800e+04  21495  21495.000000  21498.000000  21498.000000
# unique           NaN      2           NaN           NaN           NaN
# top              NaN      F           NaN           NaN           NaN
# freq             NaN  11116           NaN           NaN           NaN
# mean    5.385941e+16    NaN     43.097139     20.147270    443.052284
# std     5.339410e+18    NaN     10.798968     18.759501    840.248942
# min    -9.221942e+18    NaN     21.000000     -1.000000     -1.000000
# 50%     4.578641e+16    NaN     42.000000     16.000000    123.000000
# max     9.223107e+18    NaN     66.000000    101.000000   4662.000000
#
#        citizenship            education job_type
# count        21493                 9280       75
# unique           2                    7        5
# top         RUSSIA  HIGHER_PROFESSIONAL  RETIRED
# freq         21492                 4463       40
# ...

# %%
pd.read_csv('train_data/com.csv').describe(include='all', percentiles=[])
# Out:
#            client_id        agr_flg          otkaz         dumaet  \
# count   1.130550e+05  113055.000000  113055.000000  113055.000000
# unique           NaN            NaN            NaN            NaN
# top              NaN            NaN            NaN            NaN
# freq             NaN            NaN            NaN            NaN
# mean    3.214712e+16       0.017363       0.130335       0.014179
# std     5.335382e+18       0.130621       0.336673       0.118229
# min    -9.221942e+18       0.000000       0.000000       0.000000
# 50%    -5.484822e+14       0.000000       0.000000       0.000000
# max     9.223107e+18       1.000000       1.000000       1.000000
#
#           ring_up_flg  not_ring_up_flg     count_comm month_end_dt channel  \
# count   113055.000000    113055.000000  113055.000000       113055  113055
# unique            NaN              NaN            NaN           12       4
# top               NaN              NaN            NaN   2018-12-31     SMS
# ...

# %%
pd.read_csv('train_data/deals.csv').describe(include='all', percentiles=[])
# Out:
#            client_id agrmnt_start_dt agrmnt_close_dt       crncy_cd  \
# count   1.090160e+05          109016           67227  108939.000000
# unique           NaN            5502            4065            NaN
# top              NaN      2016-08-26      2018-11-03            NaN
# freq             NaN            3494            4313            NaN
# mean    1.463080e+17             NaN             NaN     812.282442
# std     5.304620e+18             NaN             NaN      25.348220
# min    -9.221942e+18             NaN             NaN      33.000000
# 50%     2.803692e+17             NaN             NaN     810.000000
# max     9.223107e+18             NaN             NaN     978.000000
#
#         agrmnt_rate_active  agrmnt_rate_passive  agrmnt_sum_rur prod_type_name
# count         30126.000000         48737.000000    1.054150e+05         100390
# unique                 NaN                  NaN             NaN             57
# ...

# %%
pd.read_csv('train_data/dict_mcc.csv').describe(include='all', percentiles=[])
# Out:
#              mcc_cd brs_mcc_group brs_mcc_subgroup
# count    915.000000           839              839
# unique          NaN            21               77
# top             NaN        Travel           Hotels
# freq            NaN           558              290
# mean    4441.145355           NaN              NaN
# std     1691.805795           NaN              NaN
# min       36.000000           NaN              NaN
# 50%     3678.000000           NaN              NaN
# max     9950.000000           NaN              NaN

# %%
pd.read_csv('train_data/funnel.csv').describe(include='all', percentiles=[])
# Out:
#           client_id      sale_flg    sale_amount      contacts     feature_1  \
# count  2.149800e+04  21498.000000    3519.000000  21498.000000  21498.000000
# mean   5.385941e+16      0.163690   45772.639358      1.226579      5.655317
# std    5.339410e+18      0.370002   42394.325513      0.501537      2.971824
# min   -9.221942e+18      0.000000    3035.300000      1.000000      0.000000
# 50%    4.578641e+16      0.000000   31864.600000      1.000000      6.000000
# max    9.223107e+18      1.000000  303530.750000      5.000000     14.000000
#
#        client_segment     feature_2     feature_3     feature_4     feature_5  \
# count    21498.000000  2.149800e+04  2.149800e+04  2.149800e+04  2.149800e+04
# mean         8.628058  3.189394e+06  5.511252e+04  2.384547e+04  2.111614e+04
# std          5.266742  2.090728e+06  1.713316e+05  5.141348e+04  6.249314e+04
# min          1.000000  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
pd.read_csv('train_data/payments.csv').describe(include='all', percentiles=[])
# Out:
#            client_id      day_dt       sum_rur       pmnts_name
# count   1.880680e+05      188068  1.880680e+05           188068
# unique           NaN         257           NaN                2
# top              NaN  2019-03-13           NaN  Salary receipts
# freq             NaN        2672           NaN           181662
# mean    6.852522e+16         NaN  3.006848e+04              NaN
# std     5.309421e+18         NaN  1.243982e+05              NaN
# min    -9.220236e+18         NaN  0.000000e+00              NaN
# 50%     7.519884e+16         NaN  1.760600e+04              NaN
# max     9.223107e+18         NaN  3.230101e+07              NaN

# %%
pd.read_csv('train_data/trxn.csv').describe(include='all', percentiles=[])
# Out:
# /usr/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            client_id       card_id            tran_time  tran_amt_rur  \
# count   3.035705e+06  3.035705e+06              3035705  3.035705e+06
# unique           NaN           NaN              2082989           NaN
# top              NaN           NaN  2019-02-28 00:00:00           NaN
# freq             NaN           NaN                 5665           NaN
# mean    5.292171e+16 -2.451652e+16                  NaN  2.744740e+03
# std     5.297735e+18  5.329969e+18                  NaN  1.501182e+04
# min    -9.220236e+18 -9.222934e+18                  NaN  0.000000e+00
# 50%     1.095425e+17 -9.643399e+16                  NaN  4.860000e+02
# max     9.223107e+18  9.223198e+18                  NaN  7.527563e+06
#
# ...
